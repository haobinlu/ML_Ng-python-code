# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.linspace(0,1,100)
Y = -1 * np.log10(X)
fig, ax = plt.subplots(figsize = (12,9))
ax.plot(X, Y, 'r')
plt.show()
# Out:
# D:\pycharm\pro\test\venv\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
